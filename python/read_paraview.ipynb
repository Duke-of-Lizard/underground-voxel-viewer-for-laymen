# %%
import pyvista as pv

# %%
path_vtu_in = 'test-unstructured-grid-prediction-old.vtu'

# %%
ugrid = pv.read(path_vtu_in)
ugrid
# Out:
# /Users/craigchristensen/virtual-envs/dev_EMerald_Interpret_2023-12-06-v.0.14.3/lib/python3.9/site-packages/pyvista/core/dataset.py:850: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(arr), np.nanmax(arr)
# UnstructuredGrid (0x12595d100)
#   N Cells:    2429072
#   N Points:   1311405
#   X Bounds:   5.668e+05, 5.733e+05
#   Y Bounds:   6.658e+06, 6.671e+06
#   Z Bounds:   -8.599e+01, 1.668e+02
#   N Arrays:   59

# %%
ugrid.point_data['resist_log10']
# Out:
# pyvista_ndarray([1.45069975, 2.29297151, 2.29297151, ..., 2.05553043,
#                  2.01860276, 1.79355032])

# %%
ugrid.plot(scalars='resist_log10')
# Out:
# /Users/craigchristensen/virtual-envs/dev_EMerald_Interpret_2023-12-06-v.0.14.3/lib/python3.9/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame.ui.vuetify'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
ugrid.plot(scalars='proba_1', cmap='coolwarm')
# Out:
# /Users/craigchristensen/virtual-envs/dev_EMerald_Interpret_2023-12-06-v.0.14.3/lib/python3.9/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame.ui.vuetify'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
ugrid.points
# Out:
# pyvista_ndarray([[5.68146983e+05, 6.67092411e+06, 1.36932617e+02],
#                  [5.68146983e+05, 6.67092411e+06, 1.35932617e+02],
#                  [5.68146983e+05, 6.67092411e+06, 1.34932617e+02],
#                  ...,
#                  [5.73345015e+05, 6.65954786e+06, 7.45856628e+01],
#                  [5.73265779e+05, 6.65938992e+06, 6.68448715e+01],
#                  [5.72462412e+05, 6.65862546e+06, 6.27784538e+01]])

# %%
ugrid.point_data['proba_1']
# Out:
# pyvista_ndarray([0.24114961, 0.04299475, 0.04299475, ..., 0.03988814,
#                  0.08934846, 0.54505738])

# %%
ugrid.cell_centers()
# Out:
# PolyData (0x138c689a0)
#   N Cells:    2429072
#   N Points:   2429072
#   N Strips:   0
#   X Bounds:   5.668e+05, 5.733e+05
#   Y Bounds:   6.658e+06, 6.671e+06
#   Z Bounds:   -8.452e+01, 1.651e+02
#   N Arrays:   0

# %% [markdown]
# # open structured grid

# %%
sgrid_vts_path = 'Paraview_meshes_voxels/test-structured-grid-prediction.vts'

# %%
sgrid = pv.read(sgrid_vts_path)
sgrid
# Out:
# StructuredGrid (0x125dc9280)
#   N Cells:      23063480
#   N Points:     23317200
#   X Bounds:     5.669e+05, 5.733e+05
#   Y Bounds:     6.658e+06, 6.671e+06
#   Z Bounds:     -8.680e+01, 1.662e+02
#   Dimensions:   425, 216, 254
#   N Arrays:     5

# %%
sgrid.point_data_to_cell_data()
# Out:
# StructuredGrid (0x13449ffa0)
#   N Cells:      23063480
#   N Points:     23317200
#   X Bounds:     5.669e+05, 5.733e+05
#   Y Bounds:     6.658e+06, 6.671e+06
#   Z Bounds:     -8.680e+01, 1.662e+02
#   Dimensions:   425, 216, 254
#   N Arrays:     5

# %%
sgrid_threshold = sgrid.threshold()

# %%
sgrid_threshold.plot(scalars='res')
# Out:
# /Users/craigchristensen/virtual-envs/dev_EMerald_Interpret_2023-12-06-v.0.14.3/lib/python3.9/site-packages/pyvista/jupyter/notebook.py:58: UserWarning: Failed to use notebook backend:
#
# No module named 'trame.ui.vuetify'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
